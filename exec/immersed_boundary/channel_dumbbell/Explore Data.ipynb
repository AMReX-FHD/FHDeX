# %% [markdown]
# # An Exploration of Fluctuating Channel Flow

# %% [markdown]
# This is a sandbox for exploring the fluctuating channel flow data. Data is loaded using the YT package. You might need to install (using `pip`):
# 1. Jupyter (and Jupyter Lab)
# 2. YT
# 3. numpy
# 4. matplotlib
#
# ... Have fun!

# %% [markdown]
# ## Import Basics

# %%
import sys, os, os.path
import glob

import scipy as sp
import numpy as np

import matplotlib
import matplotlib.pyplot as pp

import yt
from yt.frontends.boxlib.data_structures import AMReXDataset

# %% [markdown]
# Inline plots and namespace:

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Utilities

# %% [markdown]
# Replace `phi` with `concentration` in plot file's header file (yt doesn't like `phi`...)

# %%
### Replace "phi" with "concentration" in plt header file (yt doesn't like phi...)
def substitute_header(plt_file, source="phi", target="con"):
    
    # load header file
    header_file = os.path.join(plt_file, "Header")
    with open(header_file, "r") as f:
        header_orig = f.readlines()
    
    # select variable lables
    n_lables   = int(header_orig[1])
    l_offset   = 2
    
    # make a backup copy(iff the source was found in original)
    if source+"\n" in header_orig:
        header_cpy  = os.path.join(plt_file, "Header.backup")
        with open(header_cpy, "w") as f:
            for line in header_orig:
                f.write(line)
    
    # replace source with target
    for i in range(l_offset, n_lables+l_offset):
        if header_orig[i] == source+"\n":
            header_orig[i] = target+"\n"
    
    # save substituted file in place of original
    with open(header_file, "w") as f:
        for line in header_orig:
            f.write(line)

# %% [markdown]
# # Find Data

# %% [markdown]
# Currently we're working in the same directory as a the data $=>$ look in `.` for plot files

# %%
data_root = "."
data_dir  = "."

# %%
data_path = os.path.join(data_root, data_dir)

# %%
n_fill   = 5
prefix   = "plt"
file_fmt = prefix + "{:0" + str(n_fill) + "d}"

# %%
file_fmt
# Out:
# 'plt{:05d}'

# %%
data_glob  = os.path.join(data_path, prefix + "*")
data_files = glob.glob(data_glob)
data_files.sort()
print(data_files)
# Out:
# ['././plt0000000', '././plt0000010', '././plt0000020', '././plt0000030', '././plt0000040', '././plt0000050', '././plt0000060', '././plt0000070', '././plt0000080', '././plt0000090', '././plt0000100', '././plt0000110', '././plt0000120', '././plt0000130', '././plt0000140', '././plt0000150', '././plt0000160', '././plt0000170', '././plt0000180', '././plt0000190', '././plt0000200', '././plt0000210', '././plt0000220', '././plt0000230', '././plt0000240']

# %% [markdown]
# ## Plot Final State of the Simulation

# %%
def plot_index(data_file, str_field, str_coord):
    substitute_header(data_file)
    
    # Loads the data file
    ds = yt.load(data_file)
    
    # Takes a slice perpendicular to the coordinate represented by `str_coord`
    # -> the slice is at the center of the box.
    # -> the data field being sliced has to have the same name as `str_field`
    slc = yt.SlicePlot(ds, str_coord, str_field)
    
    # Set the plotted variable to log scale
    #slc.set_log(str_field, True)
    
    # Show data
    slc.show()
    #slc.save("step_0.png")

# %% [markdown]
# Let's find out what fields are contained in the plot file

# %%
ds = yt.load(data_files[-1])
ds.field_list
# Out:
# yt : [INFO     ] 2019-07-02 21:52:35,228 Parameters: current_time              = 2.399999999999993
# yt : [INFO     ] 2019-07-02 21:52:35,229 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 21:52:35,231 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 21:52:35,232 Parameters: domain_right_edge         = [1. 1. 1.]
# [('boxlib', 'averaged_velx'),
#  ('boxlib', 'averaged_vely'),
#  ('boxlib', 'averaged_velz'),
#  ('boxlib', 'divergence'),
#  ('boxlib', 'pres'),
#  ('boxlib', 'shifted_velx'),
#  ('boxlib', 'shifted_vely'),
#  ('boxlib', 'shifted_velz'),
#  ('boxlib', 'tracer')]

# %% [markdown]
# Plot the last plot file's $y$-velocity (slicing normal the $y$-axis).

# %%
plot_index(data_files[-1], "shifted_vely", "y")
# Out:
# yt : [INFO     ] 2019-07-02 21:52:35,776 Parameters: current_time              = 2.399999999999993
# yt : [INFO     ] 2019-07-02 21:52:35,777 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 21:52:35,779 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 21:52:35,780 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 21:52:36,047 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-07-02 21:52:36,048 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-07-02 21:52:36,051 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-07-02 21:52:36,052 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-07-02 21:52:36,055 Making a fixed resolution buffer of (('boxlib', 'shifted_vely')) 800 by 800
# yt : [WARNING  ] 2019-07-02 21:52:36,087 Plot image for field ('boxlib', 'shifted_vely') has no positive values.  Max = -0.007812.
# yt : [WARNING  ] 2019-07-02 21:52:36,088 Switching to linear colorbar scaling.
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# Let's do the same for the presure

# %%
plot_index(data_files[-1], "pres", "x")
# Out:
# yt : [INFO     ] 2019-07-02 21:52:38,031 Parameters: current_time              = 2.399999999999993
# yt : [INFO     ] 2019-07-02 21:52:38,032 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 21:52:38,035 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 21:52:38,036 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 21:52:38,306 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-07-02 21:52:38,307 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-07-02 21:52:38,310 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-07-02 21:52:38,311 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-07-02 21:52:38,314 Making a fixed resolution buffer of (('boxlib', 'pres')) 800 by 800
# yt : [WARNING  ] 2019-07-02 21:52:38,352 Plot image for field ('boxlib', 'pres') has both positive and negative values. Min = -0.484375, Max = 0.484375.
# yt : [WARNING  ] 2019-07-02 21:52:38,354 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# # Analyse Data

# %% [markdown]
# ... with `numpy`

# %% [markdown]
# ## Velocity fluctuations

# %%
ds = yt.load(data_files[-1])
# Out:
# yt : [INFO     ] 2019-07-02 21:52:39,419 Parameters: current_time              = 2.399999999999993
# yt : [INFO     ] 2019-07-02 21:52:39,421 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 21:52:39,422 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 21:52:39,423 Parameters: domain_right_edge         = [1. 1. 1.]

# %% [markdown]
# Get information about geometry: $\mathrm{d}x$ and index of centre

# %%
dx = np.array(
    [
        ( ds.domain_right_edge[i] - ds.domain_left_edge[i] ) / ds.domain_dimensions[i] 
        for i in range(ds.dimensionality) 
    ]
)


centre_slice = np.array([ei for ei in ds.domain_right_edge ])/2
ind_cen      = centre_slice / dx
print(ind_cen)
# Out:
# [16. 16. 16.]

# %% [markdown]
# Extract a "cube of data" from the plot file. This might seem a bit convoluted, but remember that YT is built to handle multi-level data. This function covers a given level (in our case, level 0) with a 3D grid (cube) and exports the data into a dict of `numpy` arrays. This way `cube["filed name"]` is a 3D numpy array.

# %%
cube = ds.covering_grid(level=0, fields=["shifted_velx", "shifted_vely", "shifted_velz"], 
                        left_edge=ds.domain_left_edge, dims=ds.domain_dimensions)
velx = cube["shifted_velx"]
vely = cube["shifted_vely"]
velz = cube["shifted_velz"]

# %% [markdown]
# Double-check the data.

# %%
matshow(velx[:, 8, :])
colorbar()

# %%
matshow(vely[:, 8, :])
colorbar()

# %%
matshow(velz[:, 8, :])
colorbar()

# %%
class SoA:
    _pref = "particle_"
    _pos  = "position_"
    _vel  = "vel"
    def __init__(self, data):
        str_pos = self._pref+self._pos
        self.px = np.array(data[str_pos + "x"])
        self.py = np.array(data[str_pos + "y"])
        self.pz = np.array(data[str_pos + "z"])

        str_vel = self._pref+self._vel
        self.vx = np.array(data[str_vel + "x"])
        self.vy = np.array(data[str_vel + "y"])
        self.vz = np.array(data[str_vel + "z"])

        
    def __str__(self):
        return "{pos:"  + str(self.px) + "," + str(self.py) + "," + str(self.pz) + \
              "; vel:"  + str(self.vx) + "," + str(self.vy) + "," + str(self.vz) + "}"


    def __repr__(self):
        return str(self)



class Particle:
    def __init__(self, px, py, pz, vx, vy, vz):
        self.pos = np.array([px, py, pz])
        self.vel = np.array([vx, vy, vz])


    def __str__(self):
        return "P(" + str(self.pos) + "," + str(self.vel) + "," + ")"


    def __repr__(self):
        return str(self)


class AoS:
    def __init__(self, amrex_data):
        self.particles = list()
        soa = SoA(amrex_data)
        
        data = zip(soa.px, soa.py, soa.pz, soa.vx, soa.vy, soa.vz)
        for elt in data:
            self.particles.append(Particle(* elt))

# %%
ds = AMReXDataset(data_files[-1])
# Out:
# yt : [INFO     ] 2019-07-02 22:00:21,696 Parameters: current_time              = 2.399999999999993
# yt : [INFO     ] 2019-07-02 22:00:21,698 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:00:21,699 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:00:21,700 Parameters: domain_right_edge         = [1. 1. 1.]

# %%
ds.particle_fields_by_type
# Out:
# defaultdict(list,
#             {'immbdy_markers': ['particle_cpu',
#               'particle_cpu_0',
#               'particle_cpu_1',
#               'particle_forcex',
#               'particle_forcey',
#               'particle_forcez',
#               'particle_id',
#               'particle_id_0',
#               'particle_id_1',
#               'particle_position_x',
#               'particle_position_y',
#               'particle_position_z',
#               'particle_pred_forcex',
#               'particle_pred_forcey',
#               'particle_pred_forcez',
#               'particle_pred_posx',
#               'particle_pred_posy',
#               'particle_pred_posz',
#               'particle_pred_velx',
#               'particle_pred_vely',
#               'particle_pred_velz',
#               'particle_radius',
#               'particle_velx',
#               'particle_vely',
#               'particle_velz']})

# %%
ad = ds.all_data()
soa = SoA(ad)
aos = AoS(ad)

# %%
aos.particles
# Out:
# [P([0.2        0.49990632 0.5       ],[0. 0. 0.],),
#  P([0.21       0.49990549 0.5       ],[0. 0. 0.],)]

# %%
aos.particles[0].pos[0:3]
# Out:
# array([0.2       , 0.49990632, 0.5       ])

# %%
position_1=list()
position_2=list()
for data_file in data_files:
    ds = AMReXDataset(data_file)
    ad = ds.all_data()
    aos = AoS(ad)
    position_1.append(aos.particles[0].pos)
    position_2.append(aos.particles[1].pos)
# Out:
# yt : [INFO     ] 2019-07-02 22:02:07,215 Parameters: current_time              = 0.0
# yt : [INFO     ] 2019-07-02 22:02:07,216 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:07,217 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:07,218 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:07,484 Parameters: current_time              = 0.09999999999999999
# yt : [INFO     ] 2019-07-02 22:02:07,485 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:07,486 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:07,486 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:07,702 Parameters: current_time              = 0.20000000000000004
# yt : [INFO     ] 2019-07-02 22:02:07,703 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:07,704 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:07,704 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:07,936 Parameters: current_time              = 0.3000000000000001
# yt : [INFO     ] 2019-07-02 22:02:07,937 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:07,938 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:07,939 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:08,174 Parameters: current_time              = 0.4000000000000002
# yt : [INFO     ] 2019-07-02 22:02:08,175 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:08,176 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:08,177 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:08,513 Parameters: current_time              = 0.5000000000000002
# yt : [INFO     ] 2019-07-02 22:02:08,514 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:08,515 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:08,516 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:08,791 Parameters: current_time              = 0.6000000000000003
# yt : [INFO     ] 2019-07-02 22:02:08,792 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:08,793 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:08,794 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:09,086 Parameters: current_time              = 0.7000000000000004
# yt : [INFO     ] 2019-07-02 22:02:09,087 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:09,087 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:09,089 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:09,430 Parameters: current_time              = 0.8000000000000005
# yt : [INFO     ] 2019-07-02 22:02:09,430 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:09,432 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:09,433 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:09,641 Parameters: current_time              = 0.9000000000000006
# yt : [INFO     ] 2019-07-02 22:02:09,641 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:09,642 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:09,643 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:10,021 Parameters: current_time              = 1.0000000000000007
# yt : [INFO     ] 2019-07-02 22:02:10,021 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:10,023 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:10,023 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:10,225 Parameters: current_time              = 1.1000000000000008
# yt : [INFO     ] 2019-07-02 22:02:10,226 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:10,226 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:10,227 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:10,416 Parameters: current_time              = 1.2000000000000008
# yt : [INFO     ] 2019-07-02 22:02:10,416 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:10,417 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:10,418 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:10,607 Parameters: current_time              = 1.300000000000001
# yt : [INFO     ] 2019-07-02 22:02:10,607 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:10,608 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:10,609 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:10,938 Parameters: current_time              = 1.400000000000001
# yt : [INFO     ] 2019-07-02 22:02:10,939 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:10,940 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:10,941 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:11,210 Parameters: current_time              = 1.500000000000001
# yt : [INFO     ] 2019-07-02 22:02:11,211 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:11,212 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:11,213 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:11,429 Parameters: current_time              = 1.6000000000000012
# yt : [INFO     ] 2019-07-02 22:02:11,430 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:11,430 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:11,431 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:11,623 Parameters: current_time              = 1.7000000000000013
# yt : [INFO     ] 2019-07-02 22:02:11,623 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:11,624 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:11,625 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:11,849 Parameters: current_time              = 1.8000000000000014
# yt : [INFO     ] 2019-07-02 22:02:11,849 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:11,850 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:11,851 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:12,177 Parameters: current_time              = 1.9000000000000015
# yt : [INFO     ] 2019-07-02 22:02:12,178 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:12,179 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:12,180 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:12,369 Parameters: current_time              = 2.0000000000000013
# yt : [INFO     ] 2019-07-02 22:02:12,370 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:12,371 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:12,372 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:12,590 Parameters: current_time              = 2.099999999999999
# yt : [INFO     ] 2019-07-02 22:02:12,591 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:12,592 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:12,593 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:12,794 Parameters: current_time              = 2.199999999999997
# yt : [INFO     ] 2019-07-02 22:02:12,794 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:12,795 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:12,796 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:13,019 Parameters: current_time              = 2.299999999999995
# yt : [INFO     ] 2019-07-02 22:02:13,020 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:13,021 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:13,022 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-07-02 22:02:13,331 Parameters: current_time              = 2.399999999999993
# yt : [INFO     ] 2019-07-02 22:02:13,332 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-07-02 22:02:13,332 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-02 22:02:13,333 Parameters: domain_right_edge         = [1. 1. 1.]

# %%
x_1 = np.array([pos[0] for pos in position_1])
y_1 = np.array([pos[1] for pos in position_1])

x_2 = np.array([pos[0] for pos in position_2])
y_2 = np.array([pos[1] for pos in position_2])

plot(x_1, y_1)
plot(x_2, y_2)

# %%
plot(y_1)

# %% [markdown]
# ## Remove Average `vely`

# %% [markdown]
# The $y$-data might seem smooth. But there will be tiny fluctuations. In order to see those, let's compute the average in dimensions 2 and 3.

# %%
m_vely = mean(mean(vely[:, :, :], axis=1), axis=1)
#              ^^-- returns a 2D array of average velocities
#         ^^------- returns a 1D array of average velocities (the average of the previous average)
plot(m_vely)

# %% [markdown]
# Compute fluctuations: `m_vely` is applied to all `dim=1` slices

# %%
# slice-wise subtraction of the average velocity... 
# I can't think of a fancy pythonic way of doing this => I'll do it in this cumbersome way:
fluct_vely = np.zeros_like(vely)
for i in range(vely.shape[0]):
    for j in range(vely.shape[1]):
            fluct_vely[:, i, j] = vely[:, i, j] - m_vely[:]

# %%
matshow(fluct_vely[:, 8, :])
colorbar()

# %% [markdown]
# ## Compute $x$, $y$ and $z$ Temperatures (Fluctuations in `velx`, `vely`, `velz`)

# %%
t_x = mean(mean(velx[:, :, :]**2, axis=1), axis=1)
#           ^^-- returns a 2D array of average velocities
#      ^^------- returns a 1D array of average velocities (the average of the previous average)
t_x = sqrt(t_x)

# %%
t_y = mean(mean(fluct_vely[:, :, :]**2, axis=1), axis=1)
#           ^^-- returns a 2D array of average velocities
#      ^^------- returns a 1D array of average velocities (the average of the previous average)
t_y = sqrt(t_y)

# %%
t_z = mean(mean(velz[:, :, :]**2, axis=1), axis=1)
#           ^^-- returns a 2D array of average velocities
#      ^^------- returns a 1D array of average velocities (the average of the previous average)
t_z = sqrt(t_z)

# %%
plot(t_x)
plot(t_y)
plot(t_z)

# %% [markdown]
# We see that the $x$-fluctuations are supressed due to the wall $\Rightarrow{}$ needs fixing!

# %% [markdown]
# # Old Stuff $\Rightarrow{}$ Clean up at some point

# %%
def grad(phi):
    dphi_x = np.zeros_like(phi)
    dphi_y = np.zeros_like(phi)
    dphi_z = np.zeros_like(phi)
    
    dphi_x[ :-1, :, :] += phi[1:,   :, :]
    dphi_x[1:,   :, :] -= phi[ :-1, :, :]
    
    dphi_y[:,  :-1, :] += phi[:, 1:,   :]
    dphi_y[:, 1:,   :] -= phi[:,  :-1, :]
    
    dphi_z[:, :,  :-1] += phi[:, :, 1:, ]
    dphi_z[:, :, 1:  ] -= phi[:, :,  :-1]
    
    return dphi_x, dphi_y, dphi_z

# %%
grad_x, grad_y, grad_z = grad(cube["con"])

# %%
matshow(cube['con'][32, :, :])

# %%
matshow(grad_z[32, :, 65:])

# %%
matshow(cube['con'][43, :, :])

# %%
matshow(grad_z[43, :, :])

# %%
plot(grad_z[43, 30, :])

# %%
matshow(grad_z[32, :, :])

# %%
matshow(cube['con'][:, :, 45])

# %%
matshow(grad_x[:, :, 45])

# %%
def sphere_coord(i_x, i_y, i_z, dr=dx, r_c=centre_colloid):
    x = (i_x + 0.5)*dr[0] - r_c[0]
    y = (i_y + 0.5)*dr[1] - r_c[1]
    z = (i_z + 0.5)*dr[2] - r_c[2]
    
    r     = np.sqrt( x**2 + y**2 + z**2)
    theta = np.arccos(z/r)
    phi   = np.arctan2(y, x)
        
    return r, theta, phi

def r_unit(theta, phi):
    return np.array([
        np.sin(theta)*np.cos(phi),
        np.sin(theta)*np.sin(phi),
        np.cos(theta)
    ])

def theta_unit(theta, phi):
    return np.array([
        np.cos(theta)*np.cos(phi),
        np.cos(theta)*np.sin(phi),
       -np.sin(theta)
    ])

def phi_unit(phi):
    return np.array([
       -np.sin(phi),
        np.cos(phi),
        0
    ])

# %%
def grad_sphere(grad_x, grad_y, grad_z):
    grad_r     = np.zeros_like(grad_x)
    grad_phi   = np.zeros_like(grad_y)
    grad_theta = np.zeros_like(grad_z)
    
    r_dat     = np.zeros_like(grad_x)
    phi_dat   = np.zeros_like(grad_x)
    theta_dat = np.zeros_like(grad_x)
    
    for ind, x in ndenumerate(grad_x):
        y = grad_y[ind]
        z = grad_z[ind]
        
        r, theta, phi = sphere_coord(ind[0], ind[1], ind[2])
        r_vec     = r_unit(theta, phi)
        theta_vec = theta_unit(theta, phi)
        phi_vec   = phi_unit(phi)
        
        grad_r[ind]     = np.dot(np.array([x, y, z]), r_vec)
        grad_phi[ind]   = np.dot(np.array([x, y, z]), phi_vec)
        grad_theta[ind] = np.dot(np.array([x, y, z]), theta_vec)
        
        r_dat[ind]     = r
        phi_dat[ind]   = phi
        theta_dat[ind] = theta
        
    return np.array(grad_r), np.array(grad_phi), np.array(grad_theta), r_dat, phi_dat, theta_dat

# %%
grad_r, grad_phi, grad_theta, r_dat, phi_dat, theta_dat = grad_sphere(grad_x, grad_y, grad_z)

# %%
matshow(r_dat[32, :, :])

# %%
matshow(phi_dat[32, :, :])

# %%
matshow(theta_dat[32, :, :])

# %%
matshow(grad_norm[43, :, :])

# %%
matshow(grad_phi[45, :, :])

# %%
matshow(grad_theta[45, :, :])

# %%
plot(grad_theta[45, 32, :])
plot(grad_phi[45, 40, :])

# %%
plot(grad_theta[45, 40, :])
plot(grad_phi[45, 40, :])

# %%
matshow(grad_theta[:, :, 60])

# %%
matshow(grad_phi[:, :, 60])

# %%
matshow(cube['con'][:, :, 60])

# %%
matshow(r_dat[:, :, 60])

# %%
matshow(theta_dat[:, :, 60])

# %%
matshow(phi_dat[:, :, 60])

# %%
def scan_theta(r, phi, theta_range, grad_x, grad_y, grad_z, r_c=centre_colloid, dr=dx):
    scan = np.zeros_like(theta_range)
    
    for i, theta in enumerate(theta_range):
        x = r_c[0] + r * np.sin(theta)*np.cos(phi)
        y = r_c[1] + r * np.sin(theta)*np.sin(phi)
        z = r_c[2] + r * np.cos(theta)
                
        i_x = int(x / dx[0])
        i_y = int(y / dx[1])
        i_z = int(z / dx[2])
        
        dphi_x = grad_x[i_x, i_y, i_z]
        dphi_y = grad_y[i_x, i_y, i_z]
        dphi_z = grad_z[i_x, i_y, i_z]
        
        e_theta = theta_unit(theta, phi)
        scan[i] = np.dot(np.array([dphi_x, dphi_y, dphi_z]), -e_theta)
    
    return scan

# %%
x = np.linspace(0, np.pi, num=100)
y_1 = scan_theta(1.4e-3, 0.0, x, grad_x, grad_y, grad_z)
y_2 = scan_theta(1.4e-3, 0.5, x, grad_x, grad_y, grad_z)
y_3 = scan_theta(1.4e-3, 1, x, grad_x, grad_y, grad_z)

# %%
plot(np.pi-x, y_1)
plot(np.pi-x, y_2)
plot(np.pi-x, y_3)

# %%
y
# Out:
# array([-5.19956799e-12, -9.90351103e-12,  2.45341939e-11,  8.23369146e-11,
#         7.14958822e-11,  1.59297975e-10,  2.61999920e-10,  1.72984853e-10,
#         3.72419997e-10,  5.88664859e-10,  3.00852487e-10,  8.73706502e-10,
#         6.30019379e-10,  1.50342756e-09,  1.77051944e-09,  2.45637687e-09,
#         2.59605648e-09,  2.31715544e-09,  5.07192789e-09,  6.82647158e-09,
#         6.27703487e-09,  1.17232692e-08,  2.37962129e-08,  2.23885478e-08,
#         5.35642232e-08,  5.53590911e-08,  3.40695350e-08,  2.93257998e-08,
#         5.97063264e-09, -1.03368693e-08, -8.55812215e-09,  1.01674588e-08,
#        -8.58186650e-09, -6.43166241e-09,  1.32708742e-08, -2.06442949e-09,
#        -3.68020493e-09,  8.11566168e-10, -1.95380568e-08,  3.11817098e-09,
#        -6.21240799e-09, -1.30965645e-08,  1.00154766e-08, -3.32335727e-09,
#        -1.34244697e-08, -1.42038172e-08, -1.19530449e-08, -7.31007113e-09,
#        -2.25383236e-09, -2.81931432e-10])

# %%
sel = np.abs(r_dat - 1.1e-3) < 1e-3
sum(sel)
# Out:
# 39016

# %%
theta_sel = theta_dat[sel]
phi_sel   = phi_dat[sel]

grad_norm_sel  = grad_norm[sel]
grad_phi_sel   = grad_phi[sel]
grad_theta_sel = grad_theta[sel]

# %%
phi_selector = np.abs(phi_sel - 0.6) < 1e-3
sum(phi_selector)
# Out:
# 36

# %%
sorted_pts = np.array(sorted(zip(theta_sel[phi_selector], grad_theta_sel[phi_selector])))

# %%
plot(sorted_pts[:,0], sorted_pts[:,1])

# %%
plot(theta_sel[:100])
