# %%
import sys, os, os.path
import glob
import math

# %%
import scipy as sp
import numpy as np

import matplotlib
import matplotlib.pyplot as pp

# %%
import yt
from yt.frontends.boxlib.data_structures import AMReXDataset

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data_root = "/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft"
data_dir  = "PlotFiles6-24"

# %%
data_path = os.path.join(data_root, data_dir)

# %%
n_fill   = 5
prefix   = "plt"
file_fmt = prefix + "{:0" + str(n_fill) + "d}"

# %%
data_glob  = os.path.join(data_path, prefix + "*")
data_files = glob.glob(data_glob)
data_files.sort()

# %%
data_files
# Out:
# ['/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000000',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000010',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000020',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000030',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000040',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000050',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000060',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000070',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000080',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000080_Render_C.png',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000080_Render_dCdy.png',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000080_Render_dCdz.png',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000090',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000100',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000110',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000120',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000130',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000140',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000150',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000160',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000170',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000180',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000190',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000200',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000210',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000220',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000220_Render_dCdy.png',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000220_Render_dCdz.png',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000230',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000240',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000250',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000260',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000270',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000280',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000290',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000300',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000310',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000320',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000320_Render_dCdz.png',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000330',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000340',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000350',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000360',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000370',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000380',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000390',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000400',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000410',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000420',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000430',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000440',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000450',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000460',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000470',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000480',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000490',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000500',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000510',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000520',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000530',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000540',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000550',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000560',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000570',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000580',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000590',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000600',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000610',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000620',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000630',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000640',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000650',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000660',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000670',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000680',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000690',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000700',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000710',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000720',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000730',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000740',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000750',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000760',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000770',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000780',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000790',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000800',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000810',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000820',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000830',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000840',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000850',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000860',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000870',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000880',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000890',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000900',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000910',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000920',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000930',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000940',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000950',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000960',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000970',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000980',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0000990',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0001000',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0001010',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0001020',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0001030',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0001040',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/PlotFiles6-24/plt0001050']

# %% [markdown]
# ### Replace "phi" with "concentration" in plt header file (yt doesn't like phi...)
# def substitute_header(plt_file, source="phi", target="concentration"):
#
#     # load header file
#     header_file = os.path.join(plt_file, "Header")
#     with open(header_file, "r") as f:
#         header_orig = f.readlines()
#
#     # select variable lables
#     n_lables   = int(header_orig[1])
#     l_offset   = 2
#
#     # make a backup copy(iff the source was found in original)
#     if source+"\n" in header_orig:
#         header_cpy  = os.path.join(plt_file, "Header.backup")
#         with open(header_cpy, "w") as f:
#             for line in header_orig:
#                 f.write(line)
#
#     # replace source with target
#     for i in range(l_offset, n_lables+l_offset):
#         if header_orig[i] == source+"\n":
#             header_orig[i] = target+"\n"
#
#     # save substituted file in place of original
#     with open(header_file, "w") as f:
#         for line in header_orig:
#             f.write(line)

# %% [markdown]
# def plot_frame(index, data_files, n_fill):
#     prefix   = "frame_"
#     file_fmt = prefix + "{:0" + str(n_fill) + "d}.png"
#
#     # legacy
#     substitute_header(data_files[index])
#
#     ds = yt.load(data_files[index])
#
#     slc = yt.SlicePlot(ds, "x", "concentration")
#     slc.set_log("concentration", False)
#     slc.set_zlim("concentration", 1e-100, 1e-5)
#
#     #slc.show()
#     slc.save(file_fmt.format(index))

# %% [markdown]
# # for i in range(0, len(data_files)):
#     plot_frame(i, data_files, 4)

# %%
# to stitch together the movie:
#    ffmpeg -pattern_type glob -i "frame_*.png" movie.mpeg

# %%
ds = yt.load(data_files[-1])
# Out:
# yt : [INFO     ] 2019-06-24 17:06:33,639 Parameters: current_time              = 0.10500000000000198
# yt : [INFO     ] 2019-06-24 17:06:33,639 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-06-24 17:06:33,640 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-06-24 17:06:33,641 Parameters: domain_right_edge         = [1. 1. 1.]

# %%
ds.field_list
# Out:
# [('boxlib', 'C'),
#  ('boxlib', 'averaged_velx'),
#  ('boxlib', 'averaged_vely'),
#  ('boxlib', 'averaged_velz'),
#  ('boxlib', 'dCdx'),
#  ('boxlib', 'dCdy'),
#  ('boxlib', 'dCdz'),
#  ('boxlib', 'divergence'),
#  ('boxlib', 'force_ibm_x'),
#  ('boxlib', 'force_ibm_y'),
#  ('boxlib', 'force_ibm_z'),
#  ('boxlib', 'pres'),
#  ('boxlib', 'shifted_force_ibm_x'),
#  ('boxlib', 'shifted_force_ibm_y'),
#  ('boxlib', 'shifted_force_ibm_z'),
#  ('boxlib', 'shifted_velx'),
#  ('boxlib', 'shifted_vely'),
#  ('boxlib', 'shifted_velz'),
#  ('boxlib', 'tracer')]

# %%
slc = yt.SlicePlot(ds, "x", "C")
slc.set_log("C", False)
#slc.set_zlim("Dcon_N", 1e-100, 8e-6)

slc.show()
#slc.save("step_0.png")
# Out:
# yt : [INFO     ] 2019-06-24 17:06:39,919 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 17:06:39,920 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 17:06:39,921 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 17:06:39,922 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 17:06:39,924 Making a fixed resolution buffer of (('boxlib', 'C')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
slc = yt.SlicePlot(ds, "x", "dCdx")
slc.set_log("dCdx", False)
#slc.set_zlim("Dcon_N", 1e-100, 8e-6)

slc.show()
#slc.save("step_0.png")
# Out:
# yt : [INFO     ] 2019-06-24 17:06:43,427 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 17:06:43,428 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 17:06:43,429 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 17:06:43,430 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 17:06:43,431 Making a fixed resolution buffer of (('boxlib', 'dCdx')) 800 by 800
# yt : [WARNING  ] 2019-06-24 17:06:43,456 Plot image for field ('boxlib', 'dCdx') has both positive and negative values. Min = -0.008116, Max = 0.000795.
# yt : [WARNING  ] 2019-06-24 17:06:43,457 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
slc = yt.SlicePlot(ds, "x", "dCdy")
slc.set_log("dCdy", False)
#slc.set_zlim("Dcon_N", 1e-100, 8e-6)

slc.show()
#slc.save("step_0.png")
# Out:
# yt : [INFO     ] 2019-06-24 17:06:44,066 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 17:06:44,066 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 17:06:44,067 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 17:06:44,068 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 17:06:44,070 Making a fixed resolution buffer of (('boxlib', 'dCdy')) 800 by 800
# yt : [WARNING  ] 2019-06-24 17:06:44,096 Plot image for field ('boxlib', 'dCdy') has both positive and negative values. Min = -0.018955, Max = 0.015063.
# yt : [WARNING  ] 2019-06-24 17:06:44,097 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
slc = yt.SlicePlot(ds, "z", "dCdz")
slc.set_log("dCdz", False)
#slc.set_zlim("Dcon_N", 1e-100, 8e-6)

slc.show()
#slc.save("step_0.png")
# Out:
# yt : [INFO     ] 2019-06-24 17:06:44,787 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 17:06:44,788 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 17:06:44,789 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 17:06:44,789 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 17:06:44,791 Making a fixed resolution buffer of (('boxlib', 'dCdz')) 800 by 800
# yt : [WARNING  ] 2019-06-24 17:06:44,815 Plot image for field ('boxlib', 'dCdz') has both positive and negative values. Min = -0.008257, Max = 0.000797.
# yt : [WARNING  ] 2019-06-24 17:06:44,815 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
im, sc = yt.create_scene(ds, 'dCdz')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-954e9052ae08> in <module>
# ----> 1 im, sc = yt.create_scene(ds, 'dCdz')
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
sc.camera.width = (300, 'kpc')
sc.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-103-9ced7ec98981> in <module>
# ----> 1 sc.camera.width = (300, 'kpc')
#       2 sc.show()
#
# NameError: name 'sc' is not defined

# %%
slc.annotate_quiver('dCdx', 'dCdy')
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
slc = yt.SlicePlot(ds, "z", "C")
slc.set_log("C", False)
#slc.set_zlim("Dcon_N", 1e-100, 8e-6)
slc.annotate_quiver('dCdx', 'dCdy',scale=0.6)
slc.show()
# Out:
# yt : [INFO     ] 2019-06-24 17:06:47,625 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 17:06:47,626 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 17:06:47,627 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 17:06:47,627 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 17:06:47,628 Making a fixed resolution buffer of (('boxlib', 'C')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
sp= ds.sphere("c", (.1, "cm"))
p=sp["C"]
import array

from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
import matplotlib.pyplot as plt

#phi1= np.zeros(len(C), dtype = float)#np.array('d');
#theta1= np.zeros(len(C), dtype = float)
#C1= np.zeros(len(C), dtype = float)
#Cdx1= np.zeros(len(C), dtype = float)
#Cdy1= np.zeros(len(C), dtype = float)
#Cdz1= np.zeros(len(C), dtype = float)
phi1=array.array('d');
theta1=array.array('d');
C1=array.array('d');
Cdx1=array.array('d');
Cdy1=array.array('d');
Cdz1=array.array('d');
gradCmag1=array.array('d');
from yt.units import cm
cen=0.5*cm
#print(p)
#plot(p)
#plot = yt.ProfilePlot(p, "radius", "C")

#plot = yt.ProfilePlot(sp,"Psi", "C")

print("(x,  y,  z) C")

print("-----------------------")
for count in range(sp["C"].size):
   j=count
   k=count
   i=count
   phi=(math.acos((sp["z"][i]-cen)/math.sqrt((sp["x"][j]-cen)**2+(sp["y"][k]-cen)**2+(sp["z"][i]-cen)**2)))
   theta=(math.tan((sp["y"][j]-cen)/(sp["x"][i]-cen)))
   gradCmag=math.sqrt((sp["dCdx"][j])**2+(sp["dCdy"][k])**2+(sp["dCdz"][i])**2)
   phi1.append(phi)
   theta1.append(theta)
   C1.append(sp["C"][count])
   Cdx1.append(sp["dCdx"][count])
   Cdy1.append(sp["dCdy"][count])
   Cdz1.append(sp["dCdz"][count])
   gradCmag1.append(gradCmag)
  # print("(%f,  %f,  %f)    %f", (phi1, theta1, sp["C"][i]))
    
    #phi1=math.acos((sp["x"][i])/sp["z"][i])
#plot.set_unit('radius', 'cm')
#p.show()
#vec1=numpy.argsort(phi1)
#print(vec1)
#C2 = np.zeros(len(vec1), dtype = float) 
#for i in range(0, len(vec1)): 
#    C2[i]= C1[vec1[i]] 
    #print('Sorted array->', C1[vec1[i]]) 
    
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Make data.

# Plot the surface.
#surf = ax.plot_surface(phi1, theta1, Cdx1, linewidth=0, antialiased=False)#, cmap=cm.coolwarm,
                      # )
ax.scatter(theta1, phi1, gradCmag1, c='r', marker='o')
ax.set_xlabel('theta')
ax.set_ylabel('phi')
ax.set_zlabel('|gradC|')
plt.show()
#plt.scatter(phi1, Cdy1)
#axes = plt.gca()
#axes.set_xlim([0, 3.14])
#axes.set_ylim([-0.003,0.003])
# Out:
# (x,  y,  z) C
# -----------------------

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(theta1, phi1, Cdy1, c='r', marker='o')
ax.set_xlabel('theta')
ax.set_ylabel('phi')
ax.set_zlabel('dCdy')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(theta1, phi1, Cdz1, c='r', marker='o')
ax.set_xlabel('theta')
ax.set_ylabel('phi')
ax.set_zlabel('dCdz')
plt.show()
