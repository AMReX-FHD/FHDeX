# %%
import sys, os, os.path
import glob

# %%
import scipy as sp
import numpy as np

import matplotlib
import matplotlib.pyplot as pp

# %%
import yt
from yt.frontends.boxlib.data_structures import AMReXDataset

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data_root = "/home/malvarado/FHDeX/exec/immersed_boundary"
data_dir  = "channel_soft"

# %%
data_path = os.path.join(data_root, data_dir)

# %%
n_fill   = 5
prefix   = "plt"
file_fmt = prefix + "{:0" + str(n_fill) + "d}"

# %%
data_glob  = os.path.join(data_path, prefix + "*")
data_files = glob.glob(data_glob)
data_files.sort()

# %%
data_files
# Out:
# ['/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000000',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000000.old.56050586700',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000010',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000010.old.63267564774',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000020',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000020.old.47472763062',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000030',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000030.old.25557041168',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000040',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000040.old.45340704918',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000050',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000050.old.72084355354',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000060',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000060.old.83806824684',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000070',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000070.old.20672011375',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000080',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000080.old.32004499435',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000090',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000090.old.64981341362',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000100',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000100.old.91435813904',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000110',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000110.old.10304450989',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000120',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000120.old.28232145309',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000130',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000130.old.43992066383',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000140',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000140.old.25493550301',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000150',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000150.old.76181578636',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000160',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000160.old.10245060921',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000170',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000170.old.51821494102',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000180',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000180.old.99379253387',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000190',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000190.old.82669448853',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000200',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000200.old.77355122566',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000210',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000210.old.62033271790',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000220',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000220.old.44329714775',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000230',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000230.old.32571768761',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000240',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000240.old.27938508987',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000250',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000250.old.21342229843',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000260',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000260.old.56453633308',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000270',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000270.old.19962882996',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000280',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000290',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000300',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000310',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000320',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000330',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000340',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000350',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000360',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000370',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000380',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000390',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000400',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000410',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000420',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000430',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000440',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000450',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000460',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000470',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000480',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000490',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000500',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000510',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000520',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000530',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000540',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000550',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000560',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000570',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000580',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000590',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000600',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000610']

# %% [markdown]
# ### Replace "phi" with "concentration" in plt header file (yt doesn't like phi...)
# def substitute_header(plt_file, source="phi", target="concentration"):
#
#     # load header file
#     header_file = os.path.join(plt_file, "Header")
#     with open(header_file, "r") as f:
#         header_orig = f.readlines()
#
#     # select variable lables
#     n_lables   = int(header_orig[1])
#     l_offset   = 2
#
#     # make a backup copy(iff the source was found in original)
#     if source+"\n" in header_orig:
#         header_cpy  = os.path.join(plt_file, "Header.backup")
#         with open(header_cpy, "w") as f:
#             for line in header_orig:
#                 f.write(line)
#
#     # replace source with target
#     for i in range(l_offset, n_lables+l_offset):
#         if header_orig[i] == source+"\n":
#             header_orig[i] = target+"\n"
#
#     # save substituted file in place of original
#     with open(header_file, "w") as f:
#         for line in header_orig:
#             f.write(line)

# %% [markdown]
# def plot_frame(index, data_files, n_fill):
#     prefix   = "frame_"
#     file_fmt = prefix + "{:0" + str(n_fill) + "d}.png"
#
#     # legacy
#     substitute_header(data_files[index])
#
#     ds = yt.load(data_files[index])
#
#     slc = yt.SlicePlot(ds, "x", "concentration")
#     slc.set_log("concentration", False)
#     slc.set_zlim("concentration", 1e-100, 1e-5)
#
#     #slc.show()
#     slc.save(file_fmt.format(index))

# %% [markdown]
# # for i in range(0, len(data_files)):
#     plot_frame(i, data_files, 4)

# %%
# to stitch together the movie:
#    ffmpeg -pattern_type glob -i "frame_*.png" movie.mpeg

# %%
ds = yt.load(data_files[-1])
# Out:
# yt : [INFO     ] 2019-06-20 12:30:42,189 Parameters: current_time              = 0.06100000000000072
# yt : [INFO     ] 2019-06-20 12:30:42,190 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-06-20 12:30:42,191 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-06-20 12:30:42,192 Parameters: domain_right_edge         = [1. 1. 1.]

# %%
ds.field_list
# Out:
# [('boxlib', 'C'),
#  ('boxlib', 'averaged_velx'),
#  ('boxlib', 'averaged_vely'),
#  ('boxlib', 'averaged_velz'),
#  ('boxlib', 'dCdx'),
#  ('boxlib', 'dCdy'),
#  ('boxlib', 'dCdz'),
#  ('boxlib', 'divergence'),
#  ('boxlib', 'force_ibm_x'),
#  ('boxlib', 'force_ibm_y'),
#  ('boxlib', 'force_ibm_z'),
#  ('boxlib', 'pres'),
#  ('boxlib', 'shifted_force_ibm_x'),
#  ('boxlib', 'shifted_force_ibm_y'),
#  ('boxlib', 'shifted_force_ibm_z'),
#  ('boxlib', 'shifted_velx'),
#  ('boxlib', 'shifted_vely'),
#  ('boxlib', 'shifted_velz'),
#  ('boxlib', 'tracer')]

# %%
slc = yt.SlicePlot(ds, "x", "C")
slc.set_log("C", False)
#slc.set_zlim("Dcon_N", 1e-100, 8e-6)

slc.show()
#slc.save("step_0.png")
# Out:
# yt : [INFO     ] 2019-06-20 12:30:42,425 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-20 12:30:42,426 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-20 12:30:42,427 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-20 12:30:42,428 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-20 12:30:42,430 Making a fixed resolution buffer of (('boxlib', 'C')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
slc = yt.SlicePlot(ds, "x", "dCdx")
slc.set_log("dCdx", False)
#slc.set_zlim("Dcon_N", 1e-100, 8e-6)

slc.show()
#slc.save("step_0.png")
# Out:
# yt : [INFO     ] 2019-06-20 12:30:42,834 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-20 12:30:42,834 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-20 12:30:42,835 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-20 12:30:42,836 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-20 12:30:42,838 Making a fixed resolution buffer of (('boxlib', 'dCdx')) 800 by 800
# yt : [WARNING  ] 2019-06-20 12:30:42,868 Plot image for field ('boxlib', 'dCdx') has both positive and negative values. Min = -0.005493, Max = 0.000621.
# yt : [WARNING  ] 2019-06-20 12:30:42,869 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
slc = yt.SlicePlot(ds, "x", "dCdy")
slc.set_log("dCdy", False)
#slc.set_zlim("Dcon_N", 1e-100, 8e-6)

slc.show()
#slc.save("step_0.png")
# Out:
# yt : [INFO     ] 2019-06-20 12:30:43,271 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-20 12:30:43,272 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-20 12:30:43,274 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-20 12:30:43,274 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-20 12:30:43,276 Making a fixed resolution buffer of (('boxlib', 'dCdy')) 800 by 800
# yt : [WARNING  ] 2019-06-20 12:30:43,306 Plot image for field ('boxlib', 'dCdy') has both positive and negative values. Min = -0.017645, Max = 0.020765.
# yt : [WARNING  ] 2019-06-20 12:30:43,308 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
slc = yt.SlicePlot(ds, "z", "dCdz")
slc.set_log("dCdz", False)
#slc.set_zlim("Dcon_N", 1e-100, 8e-6)

slc.show()
#slc.save("step_0.png")
# Out:
# yt : [INFO     ] 2019-06-20 12:30:43,782 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-20 12:30:43,782 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-20 12:30:43,784 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-20 12:30:43,784 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-20 12:30:43,786 Making a fixed resolution buffer of (('boxlib', 'dCdz')) 800 by 800
# yt : [WARNING  ] 2019-06-20 12:30:43,815 Plot image for field ('boxlib', 'dCdz') has both positive and negative values. Min = -0.005498, Max = 0.000621.
# yt : [WARNING  ] 2019-06-20 12:30:43,816 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
