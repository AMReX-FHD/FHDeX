# %%
import sys, os, os.path
import glob

# %%
import scipy as sp
import numpy as np

import matplotlib
import matplotlib.pyplot as pp

# %%
import yt
from yt.frontends.boxlib.data_structures import AMReXDataset

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data_root = "/home/malvarado/FHDeX/exec/immersed_boundary"
data_dir  = "channel_soft"

# %%
data_path = os.path.join(data_root, data_dir)

# %%
n_fill   = 5
prefix   = "plt"
file_fmt = prefix + "{:0" + str(n_fill) + "d}"

# %%
data_glob  = os.path.join(data_path, prefix + "*")
data_files = glob.glob(data_glob)
data_files.sort()

# %%
data_files
# Out:
# ['/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000000',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000010',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000020',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000030',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000040',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000050',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000060',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000070',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000080',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000080_Render_C.png',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000080_Render_dCdy.png',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000080_Render_dCdz.png',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000090',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000100',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000110',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000120',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000130',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000140',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000150',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000160',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000170',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000180',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000190',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000200',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000210',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000220',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000220_Render_dCdy.png',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000220_Render_dCdz.png',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000230',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000240',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000250',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000260',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000270',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000280',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000290',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000300',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000310',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000320']

# %% [markdown]
# ### Replace "phi" with "concentration" in plt header file (yt doesn't like phi...)
# def substitute_header(plt_file, source="phi", target="concentration"):
#
#     # load header file
#     header_file = os.path.join(plt_file, "Header")
#     with open(header_file, "r") as f:
#         header_orig = f.readlines()
#
#     # select variable lables
#     n_lables   = int(header_orig[1])
#     l_offset   = 2
#
#     # make a backup copy(iff the source was found in original)
#     if source+"\n" in header_orig:
#         header_cpy  = os.path.join(plt_file, "Header.backup")
#         with open(header_cpy, "w") as f:
#             for line in header_orig:
#                 f.write(line)
#
#     # replace source with target
#     for i in range(l_offset, n_lables+l_offset):
#         if header_orig[i] == source+"\n":
#             header_orig[i] = target+"\n"
#
#     # save substituted file in place of original
#     with open(header_file, "w") as f:
#         for line in header_orig:
#             f.write(line)

# %% [markdown]
# def plot_frame(index, data_files, n_fill):
#     prefix   = "frame_"
#     file_fmt = prefix + "{:0" + str(n_fill) + "d}.png"
#
#     # legacy
#     substitute_header(data_files[index])
#
#     ds = yt.load(data_files[index])
#
#     slc = yt.SlicePlot(ds, "x", "concentration")
#     slc.set_log("concentration", False)
#     slc.set_zlim("concentration", 1e-100, 1e-5)
#
#     #slc.show()
#     slc.save(file_fmt.format(index))

# %% [markdown]
# # for i in range(0, len(data_files)):
#     plot_frame(i, data_files, 4)

# %%
# to stitch together the movie:
#    ffmpeg -pattern_type glob -i "frame_*.png" movie.mpeg

# %%
ds = yt.load(data_files[-1])
# Out:
# yt : [INFO     ] 2019-06-24 13:18:52,566 Parameters: current_time              = 0.03199999999999989
# yt : [INFO     ] 2019-06-24 13:18:52,566 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-06-24 13:18:52,567 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-06-24 13:18:52,568 Parameters: domain_right_edge         = [1. 1. 1.]

# %%
ds.field_list
# Out:
# [('boxlib', 'C'),
#  ('boxlib', 'averaged_velx'),
#  ('boxlib', 'averaged_vely'),
#  ('boxlib', 'averaged_velz'),
#  ('boxlib', 'dCdx'),
#  ('boxlib', 'dCdy'),
#  ('boxlib', 'dCdz'),
#  ('boxlib', 'divergence'),
#  ('boxlib', 'force_ibm_x'),
#  ('boxlib', 'force_ibm_y'),
#  ('boxlib', 'force_ibm_z'),
#  ('boxlib', 'pres'),
#  ('boxlib', 'shifted_force_ibm_x'),
#  ('boxlib', 'shifted_force_ibm_y'),
#  ('boxlib', 'shifted_force_ibm_z'),
#  ('boxlib', 'shifted_velx'),
#  ('boxlib', 'shifted_vely'),
#  ('boxlib', 'shifted_velz'),
#  ('boxlib', 'tracer')]

# %%
slc = yt.SlicePlot(ds, "x", "C")
slc.set_log("C", False)
#slc.set_zlim("Dcon_N", 1e-100, 8e-6)

slc.show()
#slc.save("step_0.png")
# Out:
# yt : [INFO     ] 2019-06-24 13:18:52,986 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 13:18:52,986 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 13:18:52,988 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 13:18:52,988 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 13:18:52,990 Making a fixed resolution buffer of (('boxlib', 'C')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
slc = yt.SlicePlot(ds, "x", "dCdx")
slc.set_log("dCdx", False)
#slc.set_zlim("Dcon_N", 1e-100, 8e-6)

slc.show()
#slc.save("step_0.png")
# Out:
# yt : [INFO     ] 2019-06-24 13:18:53,461 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 13:18:53,462 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 13:18:53,463 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 13:18:53,464 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 13:18:53,466 Making a fixed resolution buffer of (('boxlib', 'dCdx')) 800 by 800
# yt : [WARNING  ] 2019-06-24 13:18:53,504 Plot image for field ('boxlib', 'dCdx') has both positive and negative values. Min = -0.005159, Max = 0.000358.
# yt : [WARNING  ] 2019-06-24 13:18:53,505 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
slc = yt.SlicePlot(ds, "x", "dCdy")
slc.set_log("dCdy", False)
#slc.set_zlim("Dcon_N", 1e-100, 8e-6)

slc.show()
#slc.save("step_0.png")
# Out:
# yt : [INFO     ] 2019-06-24 13:18:53,916 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 13:18:53,917 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 13:18:53,918 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 13:18:53,918 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 13:18:53,919 Making a fixed resolution buffer of (('boxlib', 'dCdy')) 800 by 800
# yt : [WARNING  ] 2019-06-24 13:18:53,957 Plot image for field ('boxlib', 'dCdy') has both positive and negative values. Min = -0.015388, Max = 0.017140.
# yt : [WARNING  ] 2019-06-24 13:18:53,960 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
slc = yt.SlicePlot(ds, "z", "dCdz")
slc.set_log("dCdz", False)
#slc.set_zlim("Dcon_N", 1e-100, 8e-6)

slc.show()
#slc.save("step_0.png")
# Out:
# yt : [INFO     ] 2019-06-24 13:18:54,395 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 13:18:54,398 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 13:18:54,400 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 13:18:54,402 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-24 13:18:54,404 Making a fixed resolution buffer of (('boxlib', 'dCdz')) 800 by 800
# yt : [WARNING  ] 2019-06-24 13:18:54,451 Plot image for field ('boxlib', 'dCdz') has both positive and negative values. Min = -0.005169, Max = 0.000358.
# yt : [WARNING  ] 2019-06-24 13:18:54,454 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
im, sc = yt.create_scene(ds, 'dCdz')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-954e9052ae08> in <module>
# ----> 1 im, sc = yt.create_scene(ds, 'dCdz')
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
sc.camera.width = (300, 'kpc')
sc.show()
# Out:
# <Scene Object>:
# Sources:
#     source_00: <Volume Source>:YTRegion (plt0000320): , center=[0.5 0.5 0.5] cm, left_edge=[0. 0. 0.] cm, right_edge=[1. 1. 1.] cm transfer_function:<Color Transfer Function Object>:
# x_bounds:[-4.1, -1.8] nbins:512 features:
# 	('gaussian', 'location(x):-4.1', 'width(x):0.002', 'height(y):(0.073,   0, 0.084, 0.001)')
# 	('gaussian', 'location(x):-3.8', 'width(x):0.002', 'height(y):(0.35,   0, 0.62, 0.0022)')
# 	('gaussian', 'location(x):-3.6', 'width(x):0.002', 'height(y):(  0, 0.26, 0.87, 0.0046)')
# 	('gaussian', 'location(x):-3.3', 'width(x):0.002', 'height(y):(  0, 0.65, 0.72, 0.01)')
# 	('gaussian', 'location(x):-3.1', 'width(x):0.002', 'height(y):(  0, 0.6, 0.031, 0.022)')
# 	('gaussian', 'location(x):-2.8', 'width(x):0.002', 'height(y):(  0, 0.87,   0, 0.046)')
# 	('gaussian', 'location(x):-2.6', 'width(x):0.002', 'height(y):(0.78, 0.98,   0, 0.1)')
# 	('gaussian', 'location(x):-2.3', 'width(x):0.002', 'height(y):(  1, 0.71,   0, 0.22)')
# 	('gaussian', 'location(x):-2.1', 'width(x):0.002', 'height(y):(0.91,   0,   0, 0.46)')
# 	('gaussian', 'location(x):-1.8', 'width(x):0.002', 'height(y):(0.8, 0.67, 0.67,   1)')
#
# Camera:
#     <Camera Object>:
# 	position:[1. 1. 1.] code_length
# 	focus:[0.5 0.5 0.5] code_length
# 	north_vector:[ 0.81649658 -0.40824829 -0.40824829] dimensionless
# 	width:[9.25703274e+23 9.25703274e+23 9.25703274e+23] unitary
# 	light:None
# 	resolution:(512, 512)
# Lens: <Lens Object>:
# 	lens_type:plane-parallel
# 	viewpoint:[-5.34455302e+29 -5.34455302e+29 -5.34455302e+29] code_length
