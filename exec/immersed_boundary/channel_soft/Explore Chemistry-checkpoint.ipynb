# %%
import sys, os, os.path
import glob
import math

# %%
import scipy as sp
import numpy as np

import matplotlib
import matplotlib.pyplot as pp

# %%
import yt
from yt.frontends.boxlib.data_structures import AMReXDataset

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/malvarado/anaconda3/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['cm', 'array']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
data_root = "/home/malvarado/FHDeX/exec/immersed_boundary"
data_dir  = "channel_soft"

# %%
data_path = os.path.join(data_root, data_dir)

# %%
n_fill   = 5
prefix   = "plt"
file_fmt = prefix + "{:0" + str(n_fill) + "d}"

# %%
data_glob  = os.path.join(data_path, prefix + "*")
data_files = glob.glob(data_glob)
data_files.sort()

# %%
data_files
# Out:
# ['/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000000',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000000.old.06348156929',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000010',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000020',
#  '/home/malvarado/FHDeX/exec/immersed_boundary/channel_soft/plt0000030']

# %% [markdown]
# ### Replace "phi" with "concentration" in plt header file (yt doesn't like phi...)
# def substitute_header(plt_file, source="phi", target="concentration"):
#
#     # load header file
#     header_file = os.path.join(plt_file, "Header")
#     with open(header_file, "r") as f:
#         header_orig = f.readlines()
#
#     # select variable lables
#     n_lables   = int(header_orig[1])
#     l_offset   = 2
#
#     # make a backup copy(iff the source was found in original)
#     if source+"\n" in header_orig:
#         header_cpy  = os.path.join(plt_file, "Header.backup")
#         with open(header_cpy, "w") as f:
#             for line in header_orig:
#                 f.write(line)
#
#     # replace source with target
#     for i in range(l_offset, n_lables+l_offset):
#         if header_orig[i] == source+"\n":
#             header_orig[i] = target+"\n"
#
#     # save substituted file in place of original
#     with open(header_file, "w") as f:
#         for line in header_orig:
#             f.write(line)

# %% [markdown]
# def plot_frame(index, data_files, n_fill):
#     prefix   = "frame_"
#     file_fmt = prefix + "{:0" + str(n_fill) + "d}.png"
#
#     # legacy
#     substitute_header(data_files[index])
#
#     ds = yt.load(data_files[index])
#
#     slc = yt.SlicePlot(ds, "x", "concentration")
#     slc.set_log("concentration", False)
#     slc.set_zlim("concentration", 1e-100, 1e-5)
#
#     #slc.show()
#     slc.save(file_fmt.format(index))

# %% [markdown]
# # for i in range(0, len(data_files)):
#     plot_frame(i, data_files, 4)

# %%
# to stitch together the movie:
#    ffmpeg -pattern_type glob -i "frame_*.png" movie.mpeg

# %%
ds = yt.load(data_files[-1])
# Out:
# yt : [INFO     ] 2019-06-25 17:21:39,377 Parameters: current_time              = 0.0010000000000000002
# yt : [INFO     ] 2019-06-25 17:21:39,383 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2019-06-25 17:21:39,387 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-06-25 17:21:39,388 Parameters: domain_right_edge         = [1. 1. 1.]

# %%
ds.field_list
# Out:
# [('boxlib', ''),
#  ('boxlib', ''),
#  ('boxlib', ''),
#  ('boxlib', 'C'),
#  ('boxlib', 'averaged_velx'),
#  ('boxlib', 'averaged_vely'),
#  ('boxlib', 'averaged_velz'),
#  ('boxlib', 'dCdx'),
#  ('boxlib', 'dCdy'),
#  ('boxlib', 'dCdz'),
#  ('boxlib', 'divergence'),
#  ('boxlib', 'dp_dCnLs'),
#  ('boxlib', 'force_ibm_x'),
#  ('boxlib', 'force_ibm_y'),
#  ('boxlib', 'force_ibm_z'),
#  ('boxlib', 'pres'),
#  ('boxlib', 'shifted_force_ibm_x'),
#  ('boxlib', 'shifted_force_ibm_y'),
#  ('boxlib', 'shifted_force_ibm_z'),
#  ('boxlib', 'shifted_velx'),
#  ('boxlib', 'shifted_vely'),
#  ('boxlib', 'shifted_velz'),
#  ('boxlib', 'tracer')]

# %%
slc = yt.SlicePlot(ds, "x", "C")
slc.set_log("C", False)
#slc.set_zlim("Dcon_N", 1e-100, 8e-6)

slc.show()
#slc.save("step_0.png")
# Out:
# yt : [INFO     ] 2019-06-25 17:26:59,588 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-25 17:26:59,589 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-25 17:26:59,590 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-25 17:26:59,604 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-25 17:26:59,606 Making a fixed resolution buffer of (('boxlib', 'C')) 800 by 800

# %%
slc = yt.SlicePlot(ds, "x", "dCdx")
slc.set_log("dCdx", False)
#slc.set_zlim("Dcon_N", 1e-100, 8e-6)

slc.show()
#slc.save("step_0.png")
# Out:
# yt : [INFO     ] 2019-06-25 17:21:43,231 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-25 17:21:43,232 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-25 17:21:43,234 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-25 17:21:43,239 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-25 17:21:43,241 Making a fixed resolution buffer of (('boxlib', 'dCdx')) 800 by 800
# yt : [WARNING  ] 2019-06-25 17:21:43,430 Plot image for field ('boxlib', 'dCdx') has both positive and negative values. Min = -0.001336, Max = 0.000039.
# yt : [WARNING  ] 2019-06-25 17:21:43,431 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
slc = yt.SlicePlot(ds, "x", "dCdy")
slc.set_log("dCdy", False)
#slc.set_zlim("Dcon_N", 1e-100, 8e-6)

slc.show()
#slc.save("step_0.png")
# Out:
# yt : [INFO     ] 2019-06-25 17:21:45,979 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-25 17:21:45,996 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-25 17:21:45,998 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-25 17:21:45,999 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-25 17:21:46,001 Making a fixed resolution buffer of (('boxlib', 'dCdy')) 800 by 800
# yt : [WARNING  ] 2019-06-25 17:21:46,165 Plot image for field ('boxlib', 'dCdy') has both positive and negative values. Min = -0.002816, Max = 0.000726.
# yt : [WARNING  ] 2019-06-25 17:21:46,178 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
slc = yt.SlicePlot(ds, "z", "dCdz")
slc.set_log("dCdz", False)
#slc.set_zlim("Dcon_N", 1e-100, 8e-6)

slc.show()
#slc.save("step_0.png")
# Out:
# yt : [INFO     ] 2019-06-25 17:21:48,652 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-25 17:21:48,656 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-25 17:21:48,659 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-25 17:21:48,662 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-25 17:21:48,666 Making a fixed resolution buffer of (('boxlib', 'dCdz')) 800 by 800
# yt : [WARNING  ] 2019-06-25 17:21:48,724 Plot image for field ('boxlib', 'dCdz') has both positive and negative values. Min = -0.001336, Max = 0.000039.
# yt : [WARNING  ] 2019-06-25 17:21:48,729 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
im, sc = yt.create_scene(ds, 'dCdz')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-192-954e9052ae08> in <module>
# ----> 1 im, sc = yt.create_scene(ds, 'dCdz')
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
sc.camera.width = (300, 'kpc')
sc.show()

# %%
slc.annotate_quiver('dCdx', 'dCdy')
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
slc = yt.SlicePlot(ds, "x", "dp_dCnLs")
slc.set_log("C", False)
#slc.set_zlim("Dcon_N", 1e-100, 8e-6)
slc.annotate_quiver('dCdy', 'dCdz',scale=.05)
slc.show()
# Out:
# yt : [INFO     ] 2019-06-25 17:22:53,036 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-25 17:22:53,038 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-25 17:22:53,042 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-25 17:22:53,044 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-06-25 17:22:53,049 Making a fixed resolution buffer of (('boxlib', 'dp_dCnLs')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
sp= ds.sphere("c", (.1, "cm"))
p=sp["C"]
import array

from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
import matplotlib.pyplot as plt

#phi1= np.zeros(len(C), dtype = float)#np.array('d');
#theta1= np.zeros(len(C), dtype = float)
#C1= np.zeros(len(C), dtype = float)
#Cdx1= np.zeros(len(C), dtype = float)
#Cdy1= np.zeros(len(C), dtype = float)
#Cdz1= np.zeros(len(C), dtype = float)
phi1=array.array('d');
theta1=array.array('d');
C1=array.array('d');
Cdx1=array.array('d');
Cdy1=array.array('d');
Cdz1=array.array('d');
gradCmag1=array.array('d');
from yt.units import cm
cen=0.5*cm
#print(p)
#plot(p)
#plot = yt.ProfilePlot(p, "radius", "C")

#plot = yt.ProfilePlot(sp,"Psi", "C")

print("(x,  y,  z) C")

print("-----------------------")
for count in range(sp["C"].size):
   j=count
   k=count
   i=count
   phi=(math.acos((sp["z"][k]-cen)/math.sqrt((sp["x"][i]-cen)**2+(sp["y"][j]-cen)**2+(sp["z"][k]-cen)**2)))
   theta=(math.atan2((sp["y"][j]-cen),(sp["x"][i]-cen)))
   gradCmag=math.sqrt((sp["dCdx"][j])**2+(sp["dCdy"][k])**2+(sp["dCdz"][i])**2)
   phi1.append(phi)
   theta1.append(theta)
   #print( theta, sp["y"][j]-cen, sp["x"][i]-cen, (sp["y"][j]-cen)/(sp["x"][i]-cen) )
  # print( math.sqrt((sp["x"][i]-cen)**2+(sp["y"][j]-cen)**2+(sp["z"][k]-cen)**2))
   C1.append(sp["C"][count])
   Cdx1.append(sp["dCdx"][count])
   Cdy1.append(sp["dCdy"][count])
   Cdz1.append(sp["dCdz"][count])
   gradCmag1.append(gradCmag)
  # print("(%f,  %f,  %f)    %f", (phi1, theta1, sp["C"][i]))
    
    #phi1=math.acos((sp["x"][i])/sp["z"][i])
#plot.set_unit('radius', 'cm')
#p.show()
#vec1=numpy.argsort(phi1)
#print(vec1)
#C2 = np.zeros(len(vec1), dtype = float) 
#for i in range(0, len(vec1)): 
#    C2[i]= C1[vec1[i]] 
    #print('Sorted array->', C1[vec1[i]]) 
    
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Make data.

# Plot the surface.
#surf = ax.plot_surface(phi1, theta1, Cdx1, linewidth=0, antialiased=False)#, cmap=cm.coolwarm,
                      # )
ax.scatter(theta1, phi1, gradCmag1, c='r', marker='o')
ax.set_xlabel('theta')
ax.set_ylabel('phi')
ax.set_zlabel('|gradC|')
plt.show()

#plt.scatter(phi1, Cdy1)
#axes = plt.gca()
#axes.set_xlim([0, 3.14])
#axes.set_ylim([-0.003,0.003])
# Out:
# (x,  y,  z) C
# -----------------------

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(theta1, phi1, Cdy1, c='r', marker='o')
ax.set_xlabel('theta')
ax.set_ylabel('phi')
ax.set_zlabel('dCdx')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(theta1, phi1, Cdy1, c='r', marker='o')
ax.set_xlabel('theta')
ax.set_ylabel('phi')
ax.set_zlabel('dCdy')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(theta1, phi1, Cdz1, c='r', marker='o')
ax.set_xlabel('theta')
ax.set_ylabel('phi')
ax.set_zlabel('dCdz')
plt.show()
