# %%
import yt
import numpy as np
import math
import matplotlib.pyplot as plt
# Out:
# /usr/lib/python3.8/_collections_abc.py:666: MatplotlibDeprecationWarning: The global colormaps dictionary is no longer considered public API.
#   self[key]

# %%
def return_y_plt(folder,time,nbins,field="densityMean"):
    ds = yt.load(folder+time)
    ad = ds.all_data()
    plot = yt.ProfilePlot(ad,"x",[field],weight_field="cell_volume",x_log=False,y_log={field:False},n_bins=nbins)
    profile = plot.profiles[0]
    x = np.array(profile.x)
    y = np.array(profile[field])
    return x, y

# %%
time = "/pltcu0000"+"40000000/"
x1, y1 = return_y_plt('~/gigan/projects/FHDeX/exec/DSMCt4',time,nbins=128,field="rhoMean_00")
x2, y2 = return_y_plt('~/gigan/projects/FHDeX/exec/DSMCt4',time,nbins=128,field="rhoMean_01")

time = "/pltprim0000"+"10000000/"
x5a, y5a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMCt4',time,nbins=128,field="uMean")
x4a, y4a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMCt4',time,nbins=128,field="rhoMean")
x3a, y3a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMCt4',time,nbins=128,field="TMean")

time = "/pltprim0000"+"20000000/"
x5b, y5b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMCt4',time,nbins=128,field="uMean")
x4b, y4b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMCt4',time,nbins=128,field="rhoMean")
x3b, y3b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMCt4',time,nbins=128,field="TMean")

time = "/pltprim0000"+"18000000/"
x5cB, y5cB = return_y_plt('~/gigan/projects/FHDeX/exec/DSMCt4',time,nbins=128,field="uMean")
x4cB, y4cB = return_y_plt('~/gigan/projects/FHDeX/exec/DSMCt4',time,nbins=128,field="rhoMean")
x3cB, y3cB = return_y_plt('~/gigan/projects/FHDeX/exec/DSMCt4',time,nbins=128,field="TMean")
# Out:
# yt : [INFO     ] 2022-02-11 10:54:41,550 Parameters: current_time              = 0.0007999999801463225
# yt : [INFO     ] 2022-02-11 10:54:41,551 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-02-11 10:54:41,552 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-02-11 10:54:41,554 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-02-11 10:54:42,996 Parameters: current_time              = 0.0007999999801463225
# yt : [INFO     ] 2022-02-11 10:54:42,997 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-02-11 10:54:42,998 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-02-11 10:54:42,999 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-02-11 10:54:44,010 Parameters: current_time              = 0.00019999998001276391
# ...

# %%
time = "/pltcu0000"+"08000000/"
x1, y1 = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC6',time,nbins=128,field="rhoMean_00")
x2, y2 = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC6',time,nbins=128,field="rhoMean_01")

time = "/pltprim0000"+"02000000/"
x5a, y5a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC6',time,nbins=128,field="uMean")
x4a, y4a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC6',time,nbins=128,field="rhoMean")
x3a, y3a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC6',time,nbins=128,field="TMean")

time = "/pltprim0000"+"04000000/"
x5b, y5b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC6',time,nbins=128,field="uMean")
x4b, y4b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC6',time,nbins=128,field="rhoMean")
x3b, y3b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC6',time,nbins=128,field="TMean")

time = "/pltprim0000"+"08000000/"
x5c, y5c = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC6',time,nbins=128,field="uMean")
x4c, y4c = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC6',time,nbins=128,field="rhoMean")
x3c, y3c = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC6',time,nbins=128,field="TMean")
# Out:
# yt : [INFO     ] 2022-02-17 10:25:37,739 Parameters: current_time              = 0.0003199999600199314
# yt : [INFO     ] 2022-02-17 10:25:37,740 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-02-17 10:25:37,741 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-02-17 10:25:37,742 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-02-17 10:25:39,799 Parameters: current_time              = 0.0003199999600199314
# yt : [INFO     ] 2022-02-17 10:25:39,801 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-02-17 10:25:39,802 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-02-17 10:25:39,803 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-02-17 10:25:40,881 Parameters: current_time              = 7.999996000314214e-05
# ...

# %%
time = "/pltprim0000"+"50000000/"
x5cD, y5cD = return_y_plt('~/gigan/projects/FHDeX/exec/DSMCt2',time,nbins=128,field="uMean")
x4cD, y4cD = return_y_plt('~/gigan/projects/FHDeX/exec/DSMCt2',time,nbins=128,field="rhoMean")
x3cD, y3cD = return_y_plt('~/gigan/projects/FHDeX/exec/DSMCt2',time,nbins=128,field="TMean")
# Out:
# yt : [INFO     ] 2022-02-15 10:09:42,480 Parameters: current_time              = 0.0009999999803043092
# yt : [INFO     ] 2022-02-15 10:09:42,481 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-02-15 10:09:42,483 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-02-15 10:09:42,484 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-02-15 10:09:44,496 Parameters: current_time              = 0.0009999999803043092
# yt : [INFO     ] 2022-02-15 10:09:44,497 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-02-15 10:09:44,498 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-02-15 10:09:44,499 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-02-15 10:09:45,491 Parameters: current_time              = 0.0009999999803043092
# ...

# %%
time = "/pltcu0000"+"00020000/"
x1, y1 = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC8',time,nbins=128,field="rhoMean_00")
#x2, y2 = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC8',time,nbins=128,field="rhoMean_01")

time = "/pltprim0000"+"00010000/"
x5a, y5a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC8',time,nbins=128,field="uMean")
x4a, y4a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC8',time,nbins=128,field="rhoMean")
x3a, y3a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC8',time,nbins=128,field="TMean")

time = "/pltprim0000"+"00015000/"
x5b, y5b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC8',time,nbins=128,field="uMean")
x4b, y4b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC8',time,nbins=128,field="rhoMean")
x3b, y3b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC8',time,nbins=128,field="TMean")

time = "/pltprim0000"+"00020000/"
x5cB, y5c = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC8',time,nbins=128,field="uMean")
x4cB, y4c = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC8',time,nbins=128,field="rhoMean")
x3cB, y3c = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC8',time,nbins=128,field="TMean")
# Out:
# yt : [INFO     ] 2022-03-24 12:43:28,284 Parameters: current_time              = 3.1998400000012245e-06
# yt : [INFO     ] 2022-03-24 12:43:28,286 Parameters: domain_dimensions         = [32  1  1]
# yt : [INFO     ] 2022-03-24 12:43:28,287 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-03-24 12:43:28,288 Parameters: domain_right_edge         = [9.6e-05 3.5e-06 3.5e-06]
# yt : [INFO     ] 2022-03-24 12:43:29,605 Parameters: current_time              = 1.599839999999817e-06
# yt : [INFO     ] 2022-03-24 12:43:29,607 Parameters: domain_dimensions         = [32  1  1]
# yt : [INFO     ] 2022-03-24 12:43:29,608 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-03-24 12:43:29,610 Parameters: domain_right_edge         = [9.6e-05 3.5e-06 3.5e-06]
# yt : [INFO     ] 2022-03-24 12:43:31,219 Parameters: current_time              = 1.599839999999817e-06
# ...

# %%
time = "/pltcu0000"+"00020000/"
x1, y1 = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rhoMean_00")
x2, y2 = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rhoMean_01")

time = "/pltprim0000"+"00010000/"
x5a, y5a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="uMean")
x4a, y4a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rhoMean")
x3a, y3a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="TMean")

time = "/pltprim0000"+"00020000/"
x5b, y5b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="uMean")
x4b, y4b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rhoMean")
x3b, y3b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="TMean")

#time = "/pltprim0000"+"00020000/"
#x5cB, y5c = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC8',time,nbins=32,field="uMean")
#x4cB, y4c = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC8',time,nbins=32,field="rhoMean")
#x3cB, y3c = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC8',time,nbins=32,field="TMean")
# Out:
# yt : [INFO     ] 2022-03-30 11:45:49,679 Parameters: current_time              = 1.5999200000006122e-06
# yt : [INFO     ] 2022-03-30 11:45:49,681 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-03-30 11:45:49,682 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-03-30 11:45:49,683 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-03-30 11:45:51,645 Parameters: current_time              = 1.5999200000006122e-06
# yt : [INFO     ] 2022-03-30 11:45:51,647 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-03-30 11:45:51,648 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-03-30 11:45:51,649 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-03-30 11:45:52,619 Parameters: current_time              = 7.999199999999085e-07
# ...

# %%
nc=128
LL=3.84e-04
cs=LL/nc
xDSMC=np.linspace(0.5*cs,LL-0.5*cs,nc)

# %%
filename = '/home/drladiges/Downloads/profile_neq1.txt'
data = np.loadtxt(filename, delimiter=' ', skiprows=1, dtype=str)

LL=len(data)
xFHD=[]
yFHD1=[]
yFHD2=[]
yFHD3=[]
yFHD4=[]
for i in range(LL):
    val=float(data[i,0])
    xFHD.append(val)
    val1=float(data[i,7])
    val2=float(data[i,8])
    val3=float(data[i,5])    
    rho=float(data[i,1])
    yFHD1.append(val1*rho)
    yFHD2.append(val2*rho)
    yFHD3.append(val3)
    yFHD4.append(rho)

# %%
LL=len(x1)
rhoSum=[]
for i in range(LL):
    val1=y1[i]
    val2=y2[i]
    rhoSum.append(val1+val2)
    
y1rev=y1[::-1]

# %%
y2
# Out:
# array([0.00069188, 0.00073472, 0.00065633, 0.00067456, 0.00064812,
#        0.00065086, 0.00065086, 0.00063354, 0.00064995, 0.00069461,
#        0.00063536, 0.00065086, 0.00064903, 0.00061166, 0.00063992,
#        0.0006381 , 0.00061622, 0.00061257, 0.00057976, 0.00055788,
#        0.00059069, 0.00058522, 0.00056244, 0.00060801, 0.00057611,
#        0.00059343, 0.00056426, 0.00056517, 0.00059616, 0.0005679 ,
#        0.0005278 , 0.0005515 , 0.0005515 , 0.00048586, 0.00053873,
#        0.00058705, 0.00051777, 0.00050501, 0.0005041 , 0.00051777,
#        0.0005205 , 0.00047948, 0.00050045, 0.00051139, 0.00050227,
#        0.00048222, 0.00048586, 0.00048951, 0.00048586, 0.00045305,
#        0.0004494 , 0.00045761, 0.00043299, 0.00044302, 0.00045122,
#        0.00044029, 0.00045396, 0.00040747, 0.00041567, 0.00044667,
#        0.00043026, 0.00040929, 0.000402  , 0.00040747, 0.00041203,
#        0.0003938 , 0.0003628 , 0.00038377, 0.00036189, 0.00040109,
# ...

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.20)


ax1 = fig.add_subplot(1,2,1)

ax1.plot(xDSMC,y1,color='red',linewidth=2, label='DSMC spec 0')
ax1.plot(xDSMC, y2,color='blue',linewidth=2, label='DSMC spec 1')
ax1.plot(xDSMC, y1+y2,color='blue',linewidth=2, label='DSMC total')
#ax1.plot(xDSMC,y4a,color='green',linewidth=2, label='DSMC total')
#ax1.plot(xDSMC,y4b,color='purple',linewidth=2, label='DSMC total')
#ax1.plot(xFHD,yFHD4,color='red',linewidth=2,linestyle='dashed', label='FHD spec 1')
#ax1.plot(xDSMC,rhoSum,color='blue',linewidth=2,linestyle='dashed', label='DSMC sum')


ax1.set_xlabel(r'$x$', fontsize=30)
ax1.set_ylabel(r"$\rho$", fontsize=30,rotation=0, labelpad=15)
#ax1.set_ylim([-20,1444])
#ax1.set_xlim([-0.1e-7,2e-7])
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.53,0.6),fontsize=20)
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)


ax2 = fig.add_subplot(1,2,2)


#ax2.plot(xDSMC,y3a,color='purple',linewidth=2, label='DSMC')
ax2.plot(xDSMC,y3a,color='purple',linewidth=2, label='1')
ax2.plot(xDSMC,y3b,color='green',linewidth=2, label='2')
#ax2.plot(xDSMC,y3c,color='orange',linewidth=2, label='2 million development')
ax2.plot(xFHD,yFHD3,color='black',linewidth=2,linestyle='dashed', label='FHD')

ax2.set_xlabel(r'$x$', fontsize=30)
ax2.set_ylabel(r"$T$", fontsize=30,rotation=0, labelpad=15)
#ax1.set_ylim([-20,1444])
#ax1.set_xlim([-0.1e-7,2e-7])
ax2.tick_params(labelsize=20)
ax2.legend(loc=(0.53,0.6),fontsize=20)
ax2.xaxis.set_tick_params(width=1.5)
ax2.yaxis.set_tick_params(width=1.5)

fig.savefig("profiles.pdf", bbox_inches = 'tight', pad_inches = 0.05)

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.20)


ax1 = fig.add_subplot(1,2,1)

ax1.plot(xDSMC,y1,color='red',linewidth=2, label='DSMC spec 0')
ax1.plot(xDSMC, y2,color='blue',linewidth=2, label='DSMC spec 1')
ax1.plot(xDSMC, y1+y2,color='blue',linewidth=2, label='DSMC total')
#ax1.plot(xDSMC,y4a,color='green',linewidth=2, label='DSMC total')
#ax1.plot(xDSMC,y4b,color='purple',linewidth=2, label='DSMC total')
#ax1.plot(xFHD,yFHD4,color='red',linewidth=2,linestyle='dashed', label='FHD spec 1')
#ax1.plot(xDSMC,rhoSum,color='blue',linewidth=2,linestyle='dashed', label='DSMC sum')


ax1.set_xlabel(r'$x$', fontsize=30)
ax1.set_ylabel(r"$\rho$", fontsize=30,rotation=0, labelpad=15)
#ax1.set_ylim([-20,1444])
#ax1.set_xlim([-0.1e-7,2e-7])
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.53,0.6),fontsize=20)
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)


ax2 = fig.add_subplot(1,2,2)


#ax2.plot(xDSMC,y3a,color='purple',linewidth=2, label='DSMC')
ax2.plot(xDSMC,y3a,color='purple',linewidth=2, label='1')
ax2.plot(xDSMC,y3b,color='green',linewidth=2, label='2')
#ax2.plot(xDSMC,y3c,color='orange',linewidth=2, label='2 million development')
ax2.plot(xFHD,yFHD3,color='black',linewidth=2,linestyle='dashed', label='FHD')

ax2.set_xlabel(r'$x$', fontsize=30)
ax2.set_ylabel(r"$T$", fontsize=30,rotation=0, labelpad=15)
#ax1.set_ylim([-20,1444])
#ax1.set_xlim([-0.1e-7,2e-7])
ax2.tick_params(labelsize=20)
ax2.legend(loc=(0.53,0.6),fontsize=20)
ax2.xaxis.set_tick_params(width=1.5)
ax2.yaxis.set_tick_params(width=1.5)

fig.savefig("profiles.pdf", bbox_inches = 'tight', pad_inches = 0.05)

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.20)


ax1 = fig.add_subplot(1,2,1)

#ax1.plot(xDSMC,y1,color='red',linewidth=2, label='DSMC spec 1')
#ax1.plot(xDSMC,y2,color='blue',linewidth=2, label='DSMC spec 2')
#ax1.plot(xDSMC,y5a,color='green',linewidth=2, label='DSMC total')
#ax1.plot(xDSMC,y5b,color='purple',linewidth=2, label='DSMC total')
ax1.plot(xDSMC,y5a,color='purple',linewidth=2, label='DSMC total')
ax1.plot(xDSMC,y5b,color='green',linewidth=2, label='DSMC total')
ax1.plot(xDSMC,y5c,color='orange',linewidth=2, label='DSMC total')
#ax1.plot(xDSMC,y5c,color='blue',linewidth=2, label='DSMC total')
#ax1.plot(xDSMC,y4b,color='purple',linewidth=2, label='DSMC total')
#ax1.plot(xFHD,yFHD4,color='red',linewidth=2,linestyle='dashed', label='FHD spec 1')
#ax1.plot(xDSMC,rhoSum,color='blue',linewidth=2,linestyle='dashed', label='DSMC sum')


ax1.set_xlabel(r'$x$', fontsize=30)
ax1.set_ylabel(r"$u$", fontsize=30,rotation=0, labelpad=15)
#ax1.set_ylim([-20,1444])
#ax1.set_xlim([-0.1e-7,2e-7])
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.53,0.6),fontsize=20)
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)


#ax2 = fig.add_subplot(1,2,2)

#ax2.plot(xDSMC,y3a,color='red',linewidth=2, label='DSMC')
#ax2.plot(xDSMC,y3b,color='black',linewidth=2, label='DSMC')
#ax2.plot(xDSMC,y3c,color='black',linewidth=2, label='DSMC')
#ax2.plot(xFHD,yFHD3,color='black',linewidth=2,linestyle='dashed', label='FHD')


#ax2.set_xlabel(r'$x$', fontsize=30)
#ax2.set_ylabel(r"$T$", fontsize=30,rotation=0, labelpad=15)
#ax1.set_ylim([-20,1444])
#ax1.set_xlim([-0.1e-7,2e-7])
#ax2.tick_params(labelsize=20)
#ax2.legend(loc=(0.53,0.6),fontsize=20)
#ax2.xaxis.set_tick_params(width=1.5)
#ax2.yaxis.set_tick_params(width=1.5)

fig.savefig("vel.pdf", bbox_inches = 'tight', pad_inches = 0.05)

# %%
filename = '/home/drladiges/Downloads/correl_neq1.txt'
data = np.loadtxt(filename, delimiter=' ', skiprows=1, dtype=str)

LL=len(data)
xFHDb=[]
yFHD1b=[]
yFHD2b=[]
yFHD3b=[]
for i in range(LL):
    val=float(data[i,0])
    xFHDb.append(val)
    val1=float(data[i,4])*5.8776
    val2=float(data[i,5])*5.8776
    val3=float(data[i,6])*5.8776
    yFHD1b.append(val1)
    yFHD2b.append(val2)
    yFHD3b.append(val3)

# %%
time = "/pltvar0000"+"56000000/"
x1b, y1b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMCt4',time,nbins=128,field="rho0*.rho0")
x2b, y2b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMCt4',time,nbins=128,field="rho1*.rho1")
x3b, y3b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMCt4',time,nbins=128,field="rho1*.rho0")
x4b, y4b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMCt4',time,nbins=128,field="T*.T")
x5b, y5b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMCt4',time,nbins=128,field="rho*.rho")
# Out:
# yt : [INFO     ] 2022-02-07 11:53:07,270 Parameters: current_time              = 0.0011199999798248129
# yt : [INFO     ] 2022-02-07 11:53:07,271 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-02-07 11:53:07,272 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-02-07 11:53:07,273 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-02-07 11:53:08,586 Parameters: current_time              = 0.0011199999798248129
# yt : [INFO     ] 2022-02-07 11:53:08,587 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-02-07 11:53:08,588 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-02-07 11:53:08,589 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-02-07 11:53:09,603 Parameters: current_time              = 0.0011199999798248129
# ...

# %%
yFHD3b
# Out:
# [-1.446952e-12,
#  -2.648816e-12,
#  -3.259992e-12,
#  -3.810944e-12,
#  -4.507208e-12,
#  -5.134016e-12,
#  -5.317216e-12,
#  -5.924088e-12,
#  -6.353128e-12,
#  -6.791344e-12,
#  -6.560128e-12,
#  -7.234936e-12,
#  -7.088336e-12,
#  -7.244328e-12,
#  -6.47356e-12,
#  -5.812024e-12,
#  -2.963512e-12,
#  -1.99136e-12,
#  -1.562024e-12,
#  -1.447264e-12,
#  -1.467472e-12,
#  -8.59656e-13,
#  -4.70768e-13,
#  -2.384336e-13,
#  1.325976e-14,
#  -5.326224e-13,
#  -3.9398e-14,
#  1.944024e-13,
#  1.499536e-13,
#  -8.16136e-13,
#  -6.511128e-13,
#  -5.54176e-13,
#  4.614344e-13,
#  -4.731248e-13,
#  -1.322744e-12,
#  5.829448e-13,
#  -1.25936e-13,
#  -7.884776e-13,
#  -5.139232e-13,
#  -2.007896e-13,
#  -3.486112e-13,
#  -2.816176e-13,
#  2.898224e-13,
#  7.016904e-13,
#  4.446672e-13,
#  1.108312e-12,
#  5.257568e-13,
#  1.325672e-12,
#  5.974056e-14,
#  2.655896e-13,
#  3.627704e-13,
#  1.666464e-12,
#  3.852104e-13,
#  1.805352e-12,
#  2.064976e-12,
#  2.384808e-12,
#  3.87764e-12,
# ...

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.25)


ax1 = fig.add_subplot(1,2,1)

ax1.plot(xDSMC,y1b,color='black',linewidth=2, label='DSMC')
ax1.plot(xFHDb,yFHD1b,color='black',linewidth=2,linestyle='dashed', label='FHD')



ax1.set_xlabel(r'$x$', fontsize=20)
ax1.set_ylabel(r"$<\delta \rho_0^*\delta \rho_0>$", fontsize=30,rotation=90, labelpad=10)
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.7,0.8),fontsize=20)
ax1.set_ylim([-50e-13,100e-13])
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)


#ax2 = fig.add_subplot(1,2,2)

#ax2.plot(xDSMC,y2b,color='black',linewidth=2, label='DSMC')
#ax2.plot(xFHDb,yFHD2b,color='black',linewidth=2,linestyle='dashed', label='FHD')

#ax2.set_xlabel(r'$x$', fontsize=30)
#ax2.set_ylabel(r"$<\delta \rho_1^*\delta \rho_1>$", fontsize=30,rotation=90, labelpad=10)
#ax2.set_ylim([-100e-13,100e-13])
#ax1.set_xlim([-0.1e-7,2e-7])
#ax2.tick_params(labelsize=20)
#ax2.legend(loc=(0.7,0.8),fontsize=20)
#ax2.xaxis.set_tick_params(width=1.5)
#ax2.yaxis.set_tick_params(width=1.5)


ax2 = fig.add_subplot(1,2,2)

ax2.plot(xDSMC,y5b,color='black',linewidth=2, label='DSMC')
#ax2.plot(xFHDb,yFHD3b,color='black',linewidth=2,linestyle='dashed', label='FHD')

ax2.set_xlabel(r'$x$', fontsize=30)
ax2.set_ylabel(r"$<\delta \rho_1^*\delta \rho_0>$", fontsize=30,rotation=90, labelpad=10)
ax2.set_ylim([-1e-12,1e-12])
#ax1.set_xlim([-0.1e-7,2e-7])
ax2.tick_params(labelsize=20)
ax2.legend(loc=(0.7,0.2),fontsize=20)
ax2.xaxis.set_tick_params(width=1.5)
ax2.yaxis.set_tick_params(width=1.5)

fig.savefig("correlations.pdf", bbox_inches = 'tight', pad_inches = 0.05)
